# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarra-vijendra1234/FMML-2023-22B21A4430/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 17:42:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   145MB/s    in 0.5s
#
# 2024-04-02 17:42:38 (145 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 16029  1608.05243v1  Modal sense classification (MSC) is a special ...    cs
# 6583   1703.07506v1  Multivariate binary distributions can be decom...  stat
# 3196    1305.2362v1  Blind deconvolution involves the estimation of...    cs
# 10865  1503.01916v1  Approximate Bayesian computation (ABC) is a po...  stat
# 15224  1612.05420v1  We propose a new approach for extracting argum...    cs
# ...             ...                                                ...   ...
# 212    1508.00451v4  Tackling pattern recognition problems in areas...  stat
# 6182   1609.01596v5  Artificial neural networks are most commonly t...  stat
# 12970  1709.03221v1  This paper defines software fairness and discr...    cs
# 22128  1501.02579v1  Using a Bayesian approach, we consider the pro...  stat
# 20485  1603.08714v3  We investigate properties of ABA+, a formalism...    cs
#
#                                                    title  year  \
# 16029  Multilingual Modal Sense Classification using ...  2016
# 6583                  LogitBoost autoregressive networks  2017
# 3196             Revisiting Bayesian Blind Deconvolution  2013
# 10865                                    Hamiltonian ABC  2015
# 15224  A Two-Phase Approach Towards Identifying Argum...  2016
# ...                                                  ...   ...
# 212    Integrated Inference and Learning of Neural Fa...  2015
# 6182   Direct Feedback Alignment Provides Learning in...  2016
# 12970  Fairness Testing: Testing Software for Discrim...  2017
# 22128  Combined modeling of sparse and dense noise fo...  2015
# 20485     Properties of ABA+ for Non-Monotonic Reasoning  2016
#
#                                                 keywords
# 16029  [classification, proposition, architecture, cl...
# 6583   [multivariate, distributions, decomposed, univ...
# 3196   [deconvolution, estimation, observation, funda...
# 10865  [approximate, computation, framework, performi...
# 15224  [extracting, structure, underlying, comprises,...
# ...                                                  ...
# 212    [recognition, bioinformatics, recognition, sta...
# 6182   [artificial, propagation, algorithm, propagati...
# 12970  [discrimination, measuring, discriminates, cau...
# 22128  [recovering, typically, simultaneously, estima...
# 20485  [investigate, properties, formalism, structure...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 16029    [classification, proposition, architecture, cl...
# 6583     [multivariate, distributions, decomposed, univ...
# 3196     [deconvolution, estimation, observation, funda...
# 10865    [approximate, computation, framework, performi...
# 15224    [extracting, structure, underlying, comprises,...
#                                ...
# 12790    [manipulation, deformable, important, challeng...
# 7723     [dimensional, obtaining, synthetic, descriptio...
# 6860     [approximation, investigate, algorithms, assoc...
# 6329     [generative, adversarial, limitations, sequenc...
# 366      [dimensional, ultrasound, increasing, reconstr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8709 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="34ce09bb-ad93-491a-ba75-7fc0f67eabd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ce09bb-ad93-491a-ba75-7fc0f67eabd0")) {                    Plotly.newPlot(                        "34ce09bb-ad93-491a-ba75-7fc0f67eabd0",                        [{"x":["linguistic","classifiers","classifying","convolutional","classification","favorably","architecture","proposition","previously","disambiguated","benchmark","classifier","multilingual","sophisticated","performed","complexity","similarities","differences","structures","performance","discussed","distribution","parallelized","decomposed","autoregressive","univariate","conditionals","probability","considered","conditional","trivially","estimators","estimator","dimensions","multivariate","dimension","distributions","logitboost","approaches","experimentally","framework","particular","transparent","underlying","dimensional","optimization","elucidate","methodology","selections","naturally","intuitively","prevailing","providing","enhancements","variational","compromised","rendering","estimation","improvements","invariance","convergence","estimates","avoidance","observation","heuristics","convexity","extensions","rigorously","approximations","regularize","mechanism","revisiting","difficult","arguments","parameter","marginalizes","concavity","characteristics","statistics","deconvolution","demonstrate","pertaining","challenge","successful","introducing","including","intuitions","understanding","integrals","fundamentally","transparency","substituting","principled","stochastic","approximate","relatively","gradients","performing","simulation","incorporating","comparably","efficiently","difficulty","inference","simulations","hamiltonian","computation","likelihood","introduce","effectively","algorithms","effective","embedding","comprises","argumentation","outperforms","assignment","experiments","baselines","debatepedia","relations","extracting","wikipedia","prediction","identifying","structure","strategies","different","variables","continuous","newsgroups","dirichlet","posterior","arbitrary","supervised","qualitatively","representations","categorical","discovering","advantages","unsupervised","available","quantitatively","principle","allocation","predictive","discrimination","documents","information","undirected","efficient","relationships","hypotheses","stability","distinguish","conditions","consistently","represent","occurrences","exploration","ambiguity","interpretation","plasticity","hypothesis","transient","ambiguous","indicates","topologies","repetition","objective","asynchrony","inpainting","anisotropic","algorithm","corrupted","processing","variation","interpolation","segmentation","differentiation","discrepancy","watershed","consistent","elimination","clustering","applications","artifacts","transmission","processed","diffusion","transformation","distributional","application","guarantees","consistency","generally","competitive","procedure","statistical","important"],"y":[63,130,34,384,507,19,253,5,73,1,203,153,31,31,119,221,36,52,128,911,58,191,2,8,4,5,1,155,119,88,1,17,26,36,16,65,98,0,453,50,551,258,11,108,166,354,3,68,2,53,12,5,87,8,51,2,14,214,108,24,105,65,5,55,42,13,42,7,43,5,106,12,158,21,119,2,4,83,59,7,575,6,174,67,47,263,4,166,1,8,5,2,32,125,114,60,31,72,73,54,10,156,51,216,52,6,161,67,346,124,583,257,116,13,15,278,40,617,69,2,82,66,30,235,64,334,95,739,117,97,1,23,37,97,186,23,259,12,25,67,158,286,30,57,26,46,20,61,702,11,400,55,32,37,36,135,36,114,10,60,24,60,9,59,1,17,23,8,3,174,1,12,9,820,11,289,53,19,193,4,13,3,86,8,152,450,30,11,28,22,62,19,257,62,60,63,122,113,152,374],"type":"bar"},{"x":["linguistic","classifiers","classifying","convolutional","classification" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Novel</span> <span style=''>Object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discovery</span> <span style=''>in</span> <span style=''>3D</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovering</span> <span style=''>never</span> <span style=''>seen</span> <span style=''>before</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>3D</span> <span style=''>point</span> <span style=''>clouds</span> <span style=''>obtained</span> <span style=''>from</span> <span style=''>sensors</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Microsoft</span> <span style=''>Kinect</span> <span style=''>We</span> <span style=''>generate</span> <span style=''>supervoxels</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>the</span> <span style=''>point</span> <span style=''>cloud</span> <span style=''>data</span> <span style=''>and</span> <span style=''>use</span> <span style=''>them</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Siamese</span> <span style=''>network</span> <span style=''>built</span> <span style=''>on</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>3D</span> <span style='background-color:rgba(0, 255, 0, 0.6305732484076433);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.5195195195195195);'>architecture</span> <span style=''>We</span> <span style=''>use</span> <span style=''>known</span> <span style=''>objects</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>of</span> <span style=''>supervoxels</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>criteria</span> <span style=''>that</span> <span style=''>supervoxels</span> <span style=''>which</span> <span style=''>fall</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style=''>object</span> <span style=''>should</span> <span style=''>be</span> <span style=''>closer</span> <span style=''>than</span> <span style=''>those</span> <span style=''>which</span> <span style=''>fall</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3022026431718063);'>different</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>space</span> <span style=''>We</span> <span style=''>test</span> <span style=''>on</span> <span style=''>unknown</span> <span style=''>objects</span> <span style=''>which</span> <span style=''>were</span> <span style=''>not</span> <span style=''>seen</span> <span style=''>during</span> <span style=''>training</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>the</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>space</span> <span style=''>of</span> <span style=''>supervoxels</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.46745562130177515);'>effectively</span> <span style=''>perform</span> <span style=''>novel</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>We</span> <span style=''>validate</span> <span style=''>the</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Characterizing</span> <span style=''>Implicit</span> <span style=''>Bias</span> <span style=''>in</span> <span style=''>Terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>Geometry</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>of</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>Mirror</span> <span style=''>Descent</span> <span style=''>Natural</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>and</span> <span style=''>Steepest</span> <span style=''>Descent</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentials</span> <span style=''>and</span> <span style=''>norms</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underdetermined</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>ask</span> <span style=''>the</span> <span style=''>question</span> <span style=''>of</span> <span style=''>whether</span> <span style=''>the</span> <span style=''>global</span> <span style=''>minimum</span> <span style=''>(among</span> <span style=''>the</span> <span style=''>many</span> <span style=''>possible</span> <span style=''>global</span> <span style=''>minima)</span> <span style=''>reached</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>or</span> <span style=''>norm</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style=''>choices</span> <span style=''>such</span> <span style=''>as</span> <span style=''>step</span> <span style=''>size</span> <span style=''>and</span> <span style=''>momentum</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Thompson</span> <span style=''>Sampling</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Combinatorial</span> <span style=''>Semi</span> <span style=''>Bandits</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Thompson</span> <span style=''>Sampling</span> <span style=''>(TS)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.38574938574938583);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>(CMAB)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>TS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>general</span> <span style=''>CMAB</span> <span style=''>and</span> <span style=''>obtain</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.34812286689419797);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>O(mlog</span> <span style=''>T</span> <span style=''>Delta</span> <span style=''>min)</span> <span style=''>for</span> <span style=''>TS</span> <span style=''>under</span> <span style=''>general</span> <span style=''>CMAB</span> <span style=''>where</span> <span style=''>m</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>arms</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>time</span> <span style=''>horizon</span> <span style=''>and</span> <span style=''>Delta</span> <span style=''>min</span> <span style=''>is</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>and</span> <span style=''>any</span> <span style=''>non</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>one</span> <span style=''>can</span> <span style=''>not</span> <span style=''>use</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>oracle</span> <span style=''>in</span> <span style=''>TS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>even</span> <span style=''>MAB</span> <span style=''>problems</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>expand</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>to</span> <span style=''>matroid</span> <span style=''>bandit</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>CMAB</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>use</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>to</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>When</span> <span style=''>Neurons</span> <span style=''>Fail</span> <br/><br/><span style=''>We</span> <span style=''>view</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>system</span> <span style=''>of</span> <span style=''>which</span> <span style=''>neurons</span> <span style=''>can</span> <span style=''>fail</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>and</span> <span style=''>we</span> <span style=''>evaluate</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>in</span> <span style=''>the</span> <span style=''>absence</span> <span style=''>of</span> <span style=''>any</span> <span style=''>(recovery)</span> <span style=''>learning</span> <span style=''>phase</span> <span style=''>We</span> <span style=''>give</span> <span style=''>tight</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>neurons</span> <span style=''>that</span> <span style=''>can</span> <span style=''>fail</span> <span style=''>without</span> <span style=''>harming</span> <span style=''>the</span> <span style=''>result</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>our</span> <span style=''>bounds</span> <span style=''>we</span> <span style=''>leverage</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lipschitz</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>Our</span> <span style=''>bound</span> <span style=''>is</span> <span style=''>on</span> <span style=''>a</span> <span style=''>quantity</span> <span style=''>we</span> <span style=''>call</span> <span style=''>the</span> <span style=''>textitForward</span> <span style=''>Error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capturing</span> <span style=''>how</span> <span style=''>much</span> <span style=''>error</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagated</span> <span style=''>by</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>when</span> <span style=''>a</span> <span style=''>given</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>is</span> <span style=''>failing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>this</span> <span style=''>quantity</span> <span style=''>only</span> <span style=''>requires</span> <span style=''>looking</span> <span style=''>at</span> <span style=''>the</span> <span style=''>topology</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assessing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>requires</span> <span style=''>the</span> <span style=''>costly</span> <span style='background- ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12308786908573462)
# 	processing (0.10281038776236215)
# 	experimental (0.13162575595873355)
# 	architecture (0.09000355745286374)
# 	segmentation (0.06865884027036642)
# 	information (0.2497331910352188)
# 	different (0.26289576663109215)
# 	detection (0.1248665955176094)
# 	convolutional (0.13660618996798293)
# 	recognition (0.13589469939523302)
#
# Some Statistics words are:
# 	theoretical (0.15082956259426847)
# 	estimation (0.1649069884364002)
# 	stochastic (0.14177978883861236)
# 	variables (0.13926596279537456)
# 	statistical (0.16138763197586728)
# 	algorithm (0.3991955756661639)
# 	inference (0.20512820512820512)
# 	dimensional (0.1885369532428356)
# 	distribution (0.19859225741578682)
# 	regression (0.1820010055304173)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef9ef476-9e18-4c41-917a-be8146e7e821" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef9ef476-9e18-4c41-917a-be8146e7e821")) {                    Plotly.newPlot(                        "ef9ef476-9e18-4c41-917a-be8146e7e821",                        [{"x":["linguistic","classifiers","classifying","convolutional","classification","favorably","architecture","proposition","previously","disambiguated","benchmark","classifier","multilingual","sophisticated","performed","complexity","similarities","differences","structures","performance","discussed","distribution","parallelized","decomposed","autoregressive","univariate","conditionals","probability","considered","conditional","trivially","estimators","estimator","dimensions","multivariate","dimension","distributions","logitboost","approaches","experimentally","framework","particular","transparent","underlying","dimensional","optimization","elucidate","methodology","selections","naturally","intuitively","prevailing","providing","enhancements","variational","compromised","rendering","estimation","improvements","invariance","convergence","estimates","avoidance","observation","heuristics","convexity","extensions","rigorously","approximations","regularize","mechanism","revisiting","difficult","arguments","parameter","marginalizes","concavity","characteristics","statistics","deconvolution","demonstrate","pertaining","challenge","successful","introducing","including","intuitions","understanding","integrals","fundamentally","transparency","substituting","principled","stochastic","approximate","relatively","gradients","performing","simulation","incorporating","comparably","efficiently","difficulty","inference","simulations","hamiltonian","computation","likelihood","introduce","effectively","algorithms","effective","embedding","comprises","argumentation","outperforms","assignment","experiments","baselines","debatepedia","relations","extracting","wikipedia","prediction","identifying","structure","strategies","different","variables","continuous","newsgroups","dirichlet","posterior","arbitrary","supervised","qualitatively","representations","categorical","discovering","advantages","unsupervised","available","quantitatively","principle","allocation","predictive","discrimination","documents","information","undirected","efficient","relationships","hypotheses","stability","distinguish","conditions","consistently","represent","occurrences","exploration","ambiguity","interpretation","plasticity","hypothesis","transient","ambiguous","indicates","topologies","repetition","objective","asynchrony","inpainting","anisotropic","algorithm","corrupted","processing","variation","interpolation","segmentation","differentiation","discrepancy","watershed","consistent","elimination","clustering","applications","artifacts","transmission","processed","diffusion","transformation","distributional","application","guarantees","consistency","generally","competitive","procedure","statistical","important","aforementioned","additional","reconstruction","simplifies","employing","fundamental","unconstrained","complicated","increasing","environment","interactions","furthermore","discounting","heterogeneous","constrained","coefficient","statistic","distributing","affecting","reinforcement","exploitation","importance","formulate","literature","corresponding","localisation","generating","possesses","completely","magnitude","technique","evaluating","knowledge","frameworks","proposals","localization","supervision","activation","computational","facilitate","annotations","overlapping","components","extraction","parallels","diversity","interesting","architectures","associated","rectangular","reasoning","interestingly","hierarchic ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	logitboost
# 	parallels
# 	misspecified
# 	regressions
# 	dispersion
# 	supermarket
# 	cheminformatics
# 	straggler
# 	prognostics
# 	underscore
# 	semiparametric
# 	coarsening
# 	interventional
# 	gaussianity
# 	cubically
# 	enumerated
# 	emphmulti
# 	reproducibility
# 	rademacher
# 	supersparse
# Some words which never appear in Statistics papers:
# 	prevailing
# 	avoidance
# 	argumentation
# 	debatepedia
# 	watershed
# 	disturbances
# 	occlusions
# 	appearances
# 	prolonged
# 	solomonoff
# 	conscious
# 	phonological
# 	reduplication
# 	attentive
# 	transformer
# 	presentations
# 	formalised
# 	exceptional
# 	lipreading
# 	intelligibility

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.058384561274735e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
